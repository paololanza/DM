# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime 
from collections import defaultdict
from scipy.stats import pearsonr

# %% [markdown]
# # Tweets data preparation

# %%
tweets = pd.read_csv('../tweets.csv')

# %%
tweets['id'] = pd.to_numeric(tweets['id'], errors='coerce')
tweets['user_id'] = pd.to_numeric(tweets['user_id'], errors='coerce')
tweets['retweet_count'] = pd.to_numeric(tweets['retweet_count'], errors='coerce')
tweets['reply_count'] = pd.to_numeric(tweets['reply_count'], errors='coerce')
tweets['favorite_count'] = pd.to_numeric(tweets['favorite_count'], errors='coerce')
tweets['num_hashtags'] = pd.to_numeric(tweets['num_hashtags'], errors='coerce')
tweets['num_mentions'] = pd.to_numeric(tweets['num_mentions'], errors='coerce')
tweets['num_urls'] = pd.to_numeric(tweets['num_urls'], errors='coerce')
tweets['created_at'] = pd.to_datetime(tweets['created_at'], errors='coerce')

# %%
tweets['reply_count'].describe()
# Out:
# count    12855192.0
# mean            inf
# std             NaN
# min             0.0
# 25%             0.0
# 50%             0.0
# 75%             0.0
# max             inf
# Name: reply_count, dtype: float64

# %%
tweets['reply_count'].unique()
# Out:
# array([0.0000000e+000,            nan, 1.0000000e+000, 8.0000000e+009,
#        2.0000000e+000, 8.0000000e+000, 1.8000000e+001, 4.0000000e+000,
#        1.7000000e+001, 1.0700000e+002, 1.6467330e+006, 5.2000000e+001,
#        8.5800000e+002, 3.0000000e+000, 3.3000000e+001, 5.0000000e+000,
#        6.0000000e+000, 5.3000000e+001, 1.3300000e+002, 1.6300000e+002,
#        1.4000000e+001, 1.6800000e+002, 7.0000000e+000, 9.1600000e+002,
#        5.0000000e+001, 5.5000000e+001, 7.3380000e+003, 2.5400000e+002,
#        1.1000000e+001, 2.3500000e+002, 2.6000000e+001, 8.9500000e+002,
#        7.3800000e+002, 3.6000000e+001, 1.0000000e+001, 9.0000000e+000,
#        4.7000000e+001, 7.2500000e+002, 5.9000000e+001, 9.6000000e+002,
#        1.2700000e+002, 9.1700000e+002, 1.6000000e+001, 1.5000000e+001,
#        3.1000000e+001, 8.9400000e+002, 6.5700000e+006, 2.8000000e+001,
#        4.1700000e+002, 1.2000000e+001, 3.4000000e+001, 2.2000000e+001,
#        2.4000000e+001, 7.6000000e+001, 3.9300000e+002, 2.8900000e+002,
#        7.0000000e+001, 1.6610000e+003, 2.3000000e+001, 9.6100000e+002,
#        1.3000000e+001, 6.8800000e+002, 8.6500000e+002, 2.1000000e+001,
#        5.1400000e+002, 1.1242000e+004, 6.3000000e+001, 4.0600000e+002,
#        1.1200000e+002, 3.2000000e+001, 1.1600000e+002, 2.0240000e+003,
#        3.8100000e+002, 2.0000000e+001, 6.8550000e+003, 3.1800000e+002,
#        5.6000000e+001, 2.1500000e+002, 9.0000000e+007, 2.0000000e+009,
#        1.2000000e+002, 6.1700000e+002, 5.7000000e+001, 6.2300000e+002,
#        2.5000000e+001, 2.0000000e+006, 1.9000000e+002, 5.1100000e+002,
#        3.6700000e+002, 9.2600000e+002, 1.3500000e+002, 5.4000000e+001,
#        1.0900000e+002, 3.3840000e+003, 1.0300000e+002, 4.9000000e+001,
#        2.7000000e+001, 7.2900000e+002, 1.3100000e+002, 1.2800000e+002,
#        5.7400000e+002, 9.7670000e+003, 3.1300000e+003, 6.9000000e+001,
#        8.0900000e+002, 1.6250000e+003, 3.0000000e+001, 6.6000000e+001,
#        6.5000000e+001, 3.2000000e+002, 7.6350000e+003, 3.5100000e+002,
#        5.2600000e+002, 1.2478000e+004, 5.1000000e+001, 2.9000000e+001,
#        4.8000000e+002, 6.9800000e+002, 4.7900000e+002, 2.8300000e+002,
#        3.7700000e+002, 4.5600000e+002, 4.8900000e+002, 8.3270000e+003,
#        4.3000000e+001, 1.0000000e+002, 3.8300000e+002, 4.3500000e+002,
#        1.9000000e+001, 5.8500000e+002, 3.4020000e+003, 8.2000000e+002,
#        6.2400000e+002, 1.7700000e+002, 8.6120000e+003, 8.2400000e+002,
#        8.3800000e+002, 1.7000000e+002, 3.7920000e+003, 4.1000000e+001,
#        4.6800000e+002, 8.6180000e+003, 4.1360000e+003, 8.0000000e+083,
#        3.5840000e+003, 7.9000000e+002, 8.0600000e+002, 5.6030000e+003,
#        7.0310000e+003, 1.6400000e+002, 5.0000000e+008, 1.3700000e+002,
#        1.8200000e+002, 2.4950000e+003, 1.9120000e+003, 8.5240000e+003,
#        2.0000000e+110, 5.0490000e+003, 8.8000000e+001, 5.2000000e+002,
#        3.4500000e+002, 7.3360000e+003, 1.0040000e+003, 3.6400000e+002,
#        9.8192000e+004, 1.6700000e+002, 2.4500000e+002, 2.0000000e+069,
#        3.8520000e+003, 7.0500000e+002, 1.0800000e+003, 5.1700000e+002,
#        2.3270000e+005, 4.4800000e+002, 7.0000000e+003, 4.8000000e+001,
#        7.2000000e+001, 3.7830000e+003, 7.3900000e+002, 2.6600000e+002,
#        9.0000000e+008, 1.1540000e+003, 2.9000000e+002, 2.8600000e+002,
#        4.0000000e+003, 3.7000000e+001, 9.0970000e+003, 4.6890000e+003,
#        4.1050000e+003, 4.1900000e+002, 3.9000000e+001, 3.5000000e+001,
#        9.1300000e+008, 3.4100000e+002, 8.4000000e+001, 2.2200000e+002,
#        9.0000000e+096, 4.4600000e+002, 4.5000000e+001, 2.2110000e+003,
#        1.0000000e+009, 2.6700000e+002, 5.0000000e+018, 3.8000000e+001,
#        2.0500000e+002, 8.8100000e+002, 9.1000000e+001, 4.0000000e+001,
#        2.4400000e+002, 3.3100000e+002, 7.5200000e+002, 6.9300000e+002,
#        7.3000000e+001, 8.4820000e+003, 9.7220000e+003, 2.7890000e+003,
#        6.8000000e+001, 6.6350000e+003, 9.2200000e+002, 8.4090000e+003,
#        5.8600000e+002, 1.7900000e+002, 6.0000000e+001, 1.4380000e+003,
#        2.4700000e+002, 5.5100000e+002, 7.9900000e+002, 1.7400000e+002,
#        1.1100000e+002, 1.2150000e+003, 1.6600000e+002, 1.3000000e+002,
#        8.6400000e+002, 2.0000000e+005, 4.2000000e+001, 4.1000000e+032,
#        8.0000000e+001, 4.6600000e+002, 2.7700000e+002, 8.7000000e+001,
#        1.7059000e+004, 4.0000000e+004, 8.0039200e+005, 8.5400000e+003,
#        7.9200000e+002, 9.3000000e+001, 9.1500000e+002, 6.3000000e+002,
#        3.8000000e+002, 7.7200000e+002, 2.5300000e+002, 4.3400000e+002,
#        4.6000000e+001, 4.1100000e+002, 8.4600000e+002, 5.3500000e+002,
#        4.9300000e+002, 7.1100000e+002, 2.3400000e+002, 9.7240000e+003,
#        7.6730000e+003, 8.8900000e+002, 7.0100000e+002, 9.6700000e+002,
#        1.0500000e+002, 4.0000000e+008, 7.0300000e+002, 1.4900000e+002,
#        8.0400000e+002, 2.0100000e+002,            inf, 6.0000000e+008,
#        7.1800000e+002, 8.1813700e+005, 9.0900000e+002, 2.0400000e+005,
#        2.9100000e+002, 3.0000000e+007, 8.7800000e+002, 1.0400000e+002,
#        9.5000000e+001, 8.0300000e+002, 2.3700000e+002, 1.8300000e+002,
#        7.1010000e+003, 4.3360000e+003, 8.4500000e+002, 2.0300000e+002,
#        7.9000000e+010, 2.7300000e+002, 8.8000000e+007, 4.0200000e+002,
#        6.0600000e+002, 6.2600000e+002, 8.7110000e+003, 6.1100000e+002,
#        1.8000000e+002, 6.4000000e+001, 7.7000000e+001, 5.7100000e+002,
#        2.0700000e+002, 7.9000000e+001, 7.5000000e+001, 4.3300000e+002,
#        6.1430000e+003, 6.9500000e+002, 8.6970000e+003, 4.1000000e+002,
#        2.7516000e+004, 1.0280000e+003, 5.4950000e+003, 5.2670000e+003,
#        1.0200000e+002, 5.8000000e+002, 8.4833100e+005, 5.4630000e+003,
#        2.8360000e+003, 2.8400000e+002, 4.1300000e+002, 4.0800000e+002,
#        4.6690000e+003, 7.2000000e+002, 5.1600000e+003, 2.0800000e+002,
#        5.6600000e+002, 7.5800000e+002, 2.1800000e+002, 2.7550000e+003,
#        5.0800000e+002, 4.3600000e+002, 5.5000000e+002, 3.9500000e+002,
#        1.4300000e+002, 3.5200000e+002, 2.2060000e+003, 2.4912000e+004,
#        9.3500000e+002, 7.4690000e+003, 8.2690000e+003, 8.1000000e+001,
#        6.0000000e+003, 2.6840000e+003, 9.1209500e+005, 8.0200000e+002,
#        9.7700000e+002, 6.3700000e+002, 8.1800000e+002, 3.0000000e+005,
#        7.4300000e+002, 2.3100000e+002, 2.2800000e+002, 2.4800000e+002,
#        4.0000000e+009, 9.7000000e+001, 6.9000000e+004, 9.0000000e+001,
#        5.0215000e+004, 6.4300000e+002, 8.2250000e+003, 3.2630000e+003,
#        5.1000000e+002, 7.4000000e+001, 1.2500000e+002, 7.5300000e+002,
#        2.8800000e+002, 7.9100000e+002, 8.6000000e+001, 2.4900000e+002,
#        9.3200000e+002, 5.7955000e+004, 8.4200000e+002, 4.6396000e+004,
#        9.8100000e+010, 2.1900000e+002, 1.5200000e+002, 5.1600000e+002,
#        6.9200000e+002, 5.9790000e+003, 8.9900000e+002, 6.4500000e+002,
#        2.7600000e+002, 1.0100000e+002, 3.5334000e+004, 9.0200000e+002,
#        5.0000000e+076, 7.4400000e+002, 2.1400000e+002, 4.4585999e+007,
#        5.9400000e+002, 4.4100000e+002, 6.7600000e+002, 4.2400000e+002,
#        1.4200000e+002, 2.6420000e+003, 1.5100000e+002, 7.5350000e+003,
#        2.2900000e+002, 8.9634000e+004, 2.1700000e+002, 4.4200000e+002,
#        1.8060000e+003, 1.1300000e+002, 2.9452000e+004, 7.1000000e+001,
#        8.9000000e+001, 2.3600000e+002, 8.6000000e+002, 3.3800000e+002,
#        5.8800000e+002, 2.7500000e+002, 8.8800000e+002, 3.5460000e+003,
#        7.3700000e+002, 5.3300000e+002, 9.3900000e+002, 8.5000000e+001,
#        1.0800000e+002, 4.8300000e+002, 2.4200000e+007, 6.0000000e+085,
#        2.3630000e+004, 1.8700000e+002, 3.6720000e+003, 6.4700000e+002,
#        1.0600000e+002, 4.2890000e+003, 6.4850000e+003, 6.0800000e+002,
#        3.2753500e+005, 3.5000000e+008, 5.9900000e+002, 9.2000000e+009,
#        7.0200000e+002, 7.7000000e+002, 2.7400000e+002, 6.3900000e+007,
#        3.7730000e+003, 2.5700000e+002, 6.8000000e+003, 9.2500000e+002,
#        2.8030000e+003, 7.0900000e+002, 7.8700000e+002, 9.8400000e+002,
#        1.9582000e+004, 2.0400000e+002, 9.0800000e+002, 3.9980000e+003,
#        6.0000000e+064, 2.2600000e+002, 5.0000000e+002, 4.4000000e+001,
#        5.8900000e+002, 9.9000000e+001, 3.3900000e+002, 7.2700000e+002,
#        7.9000000e+003, 2.2400000e+002, 8.3000000e+001, 1.1000000e+002,
#        3.2700000e+002, 3.7000000e+002, 6.3617800e+005, 4.9900000e+002,
#        5.6500000e+002, 2.4040000e+003, 9.4800000e+002, 4.2800000e+002,
#        7.3650500e+005, 1.5900000e+002, 7.5700000e+002, 3.6800000e+002,
#        8.2310000e+003, 8.4700000e+002, 3.5400000e+002, 5.8000000e+001,
#        1.3100000e+003, 6.6740000e+003, 9.1000000e+002, 4.5800000e+002,
#        3.1620000e+003, 5.0200000e+002, 9.5400000e+002, 5.4500000e+002,
#        9.5760000e+003, 4.2000000e+005, 6.1360000e+003, 5.3800000e+002,
#        8.8200000e+002, 8.1300000e+002, 1.0840000e+003, 3.8600000e+002,
#        9.3600000e+002, 3.0900000e+002, 5.4517900e+005, 7.4550000e+003,
#        2.8500000e+002, 1.9400000e+002, 5.0000000e+006, 3.3600000e+002,
#        5.0700000e+002, 1.9200000e+002, 1.9500000e+002, 6.9900000e+002,
#        5.6000000e+002, 6.7000000e+002, 9.6192000e+004, 6.7500000e+002,
#        3.5700000e+002, 7.8600000e+002, 7.0000000e+052, 2.3310000e+003,
#        1.1500000e+002, 7.7800000e+002, 8.9293000e+004, 1.7100000e+002,
#        7.0700000e+002, 3.7800000e+002, 1.0000000e+018, 4.4000000e+003,
#        1.9600000e+002, 5.5600000e+002, 9.0300000e+002, 9.8300000e+002,
#        9.5850000e+003, 3.1632000e+004, 8.0000000e+008, 3.9900000e+002,
#        6.7800000e+002, 5.2400000e+002, 3.2900000e+002, 8.3550000e+003,
#        8.2000000e+001, 2.6100000e+002, 8.9100000e+002, 9.9700000e+002,
#        3.8800000e+002, 9.6540000e+003, 3.0860000e+003, 4.1800000e+002,
#        8.1960000e+003, 2.4300000e+002, 9.8200000e+002, 4.7000000e+002,
#        7.1900000e+002, 1.0160000e+003, 3.3370000e+003, 2.2780000e+003,
#        4.4380000e+003, 8.2700000e+002, 5.7200000e+002, 7.0000000e+006,
#        2.4000000e+037, 6.1640000e+003, 4.2500000e+002, 7.6900000e+002,
#        8.7000000e+002, 9.0000000e+013, 2.1600000e+002, 9.0070000e+003,
#        9.5300000e+002, 6.1400000e+002, 9.9270000e+003, 4.5200000e+002,
#        7.2990000e+003, 3.1398300e+005, 1.0000000e+008, 1.7800000e+002,
#        6.3100000e+002, 4.2892000e+004, 9.6000000e+001, 6.0100000e+002,
#        6.0680000e+003, 5.6400000e+002, 8.8729000e+004, 7.6970000e+003,
#        8.4080000e+004, 1.1800000e+002, 3.4900000e+002, 3.3400000e+002,
#        4.4550700e+005, 1.5800000e+002, 7.1300000e+002, 6.2000000e+063,
#        8.8000000e+002, 1.3600000e+002, 2.7908000e+004, 9.7800000e+002,
#        3.6920000e+003, 8.3100000e+002, 2.0200000e+002, 6.8000000e+004,
#        5.6653000e+004, 4.6100000e+002, 8.7400000e+002, 5.7000000e+002,
#        4.7850000e+003, 2.5000000e+002, 2.9050000e+003, 7.2600000e+002,
#        1.7500000e+002, 6.9700000e+002, 5.9930000e+003, 4.5450000e+003,
#        9.0000000e+006, 1.7760000e+003, 7.4700000e+002, 8.7500000e+002,
#        7.6800000e+002, 4.0400000e+002, 7.9700000e+002, 7.7400000e+002,
#        4.3200000e+084, 5.7300000e+002, 1.8400000e+002, 8.0800000e+002,
#        1.5238000e+004, 5.5400000e+002, 9.0000000e+002, 1.2230000e+003,
#        9.5360000e+003, 1.4800000e+002, 1.4430000e+009, 4.0278000e+004,
#        1.6410000e+003, 1.6000000e+002, 2.7990000e+003, 3.0000000e+002,
#        2.2700000e+002, 6.6200000e+002, 7.6220000e+003, 5.9654000e+004,
#        9.7100000e+002, 5.2990000e+003, 9.2100000e+003, 7.3300000e+002,
#        5.2800000e+002, 9.8700000e+002, 7.4200000e+002, 2.1100000e+002,
#        5.1390000e+003, 9.1900000e+078, 1.8100000e+002, 5.7800000e+002,
#        2.5100000e+002, 1.8630000e+003, 6.0400000e+002, 6.7000000e+001,
#        4.1400000e+002, 8.7930000e+003, 2.7900000e+002, 4.7500000e+002,
#        1.2650000e+003, 9.8000000e+001, 9.2800000e+002, 9.5100000e+002,
#        1.3600000e+009, 6.5800000e+002, 3.0400000e+002, 9.7200000e+002,
#        4.8500000e+002, 7.0000000e+002, 6.1000000e+001, 9.7300000e+002,
#        1.2200000e+002, 2.0500000e+003, 5.0000000e+033, 9.1300000e+002,
#        5.0000000e+009, 8.3500000e+002, 1.7350000e+003, 9.4870000e+003,
#        7.9500000e+002, 3.0800000e+002, 7.3100000e+002, 1.3490000e+003,
#        9.7900000e+002, 8.4900000e+002, 7.5400000e+002, 2.0540000e+003,
#        7.5100000e+002, 1.1070000e+003, 7.4170000e+003, 7.6140000e+003,
#        1.9100000e+002, 5.3900000e+002, 8.7430000e+003, 2.7626000e+004,
#        1.2100000e+002, 6.4800000e+002, 7.7160000e+003, 5.3000000e+002,
#        6.9400000e+002, 9.0890000e+004, 5.3840000e+003, 8.4350000e+003,
#        4.8800000e+002, 3.7330000e+003, 2.4220000e+003, 1.8900000e+002,
#        5.2900000e+002, 7.6000000e+006, 7.0000000e+008, 7.8960000e+003,
#        1.2270000e+003, 9.0600000e+002, 3.7380000e+003, 4.4900000e+002,
#        7.9600000e+002, 4.4700000e+002, 8.0322000e+004, 5.7700000e+002,
#        9.6400000e+002, 6.1370000e+003, 2.6430000e+003, 8.0240000e+003,
#        7.6880000e+003, 6.9226000e+004, 3.2697000e+004, 5.4687000e+004,
#        4.4400000e+002, 5.8700000e+002, 7.0000000e+007])

# %%
tweets[tweets['reply_count'] > tweets['reply_count'].quantile(.999)]['reply_count'].unique()
# Out:
# array([8.0000000e+009, 2.0000000e+000, 8.0000000e+000, 1.8000000e+001,
#        4.0000000e+000, 1.7000000e+001, 1.0700000e+002, 1.6467330e+006,
#        5.2000000e+001, 8.5800000e+002, 3.0000000e+000, 3.3000000e+001,
#        5.0000000e+000, 6.0000000e+000, 5.3000000e+001, 1.3300000e+002,
#        1.6300000e+002, 1.4000000e+001, 1.6800000e+002, 7.0000000e+000,
#        9.1600000e+002, 5.0000000e+001, 5.5000000e+001, 7.3380000e+003,
#        2.5400000e+002, 1.1000000e+001, 2.3500000e+002, 2.6000000e+001,
#        8.9500000e+002, 7.3800000e+002, 3.6000000e+001, 1.0000000e+001,
#        9.0000000e+000, 4.7000000e+001, 7.2500000e+002, 5.9000000e+001,
#        9.6000000e+002, 1.2700000e+002, 9.1700000e+002, 1.6000000e+001,
#        1.5000000e+001, 3.1000000e+001, 8.9400000e+002, 6.5700000e+006,
#        2.8000000e+001, 4.1700000e+002, 1.2000000e+001, 3.4000000e+001,
#        2.2000000e+001, 2.4000000e+001, 7.6000000e+001, 3.9300000e+002,
#        2.8900000e+002, 7.0000000e+001, 1.6610000e+003, 2.3000000e+001,
#        9.6100000e+002, 1.3000000e+001, 6.8800000e+002, 8.6500000e+002,
#        2.1000000e+001, 5.1400000e+002, 1.1242000e+004, 6.3000000e+001,
#        4.0600000e+002, 1.1200000e+002, 3.2000000e+001, 1.1600000e+002,
#        2.0240000e+003, 3.8100000e+002, 2.0000000e+001, 6.8550000e+003,
#        3.1800000e+002, 5.6000000e+001, 2.1500000e+002, 9.0000000e+007,
#        2.0000000e+009, 1.2000000e+002, 6.1700000e+002, 5.7000000e+001,
#        6.2300000e+002, 2.5000000e+001, 2.0000000e+006, 1.9000000e+002,
#        5.1100000e+002, 3.6700000e+002, 9.2600000e+002, 1.3500000e+002,
#        5.4000000e+001, 1.0900000e+002, 3.3840000e+003, 1.0300000e+002,
#        4.9000000e+001, 2.7000000e+001, 7.2900000e+002, 1.3100000e+002,
#        1.2800000e+002, 5.7400000e+002, 9.7670000e+003, 3.1300000e+003,
#        6.9000000e+001, 8.0900000e+002, 1.6250000e+003, 3.0000000e+001,
#        6.6000000e+001, 6.5000000e+001, 3.2000000e+002, 7.6350000e+003,
#        3.5100000e+002, 5.2600000e+002, 1.2478000e+004, 5.1000000e+001,
#        2.9000000e+001, 4.8000000e+002, 6.9800000e+002, 4.7900000e+002,
#        2.8300000e+002, 3.7700000e+002, 4.5600000e+002, 4.8900000e+002,
#        8.3270000e+003, 4.3000000e+001, 1.0000000e+002, 3.8300000e+002,
#        4.3500000e+002, 1.9000000e+001, 5.8500000e+002, 3.4020000e+003,
#        8.2000000e+002, 6.2400000e+002, 1.7700000e+002, 8.6120000e+003,
#        8.2400000e+002, 8.3800000e+002, 1.7000000e+002, 3.7920000e+003,
#        4.1000000e+001, 4.6800000e+002, 8.6180000e+003, 4.1360000e+003,
#        8.0000000e+083, 3.5840000e+003, 7.9000000e+002, 8.0600000e+002,
#        5.6030000e+003, 7.0310000e+003, 1.6400000e+002, 5.0000000e+008,
#        1.3700000e+002, 1.8200000e+002, 2.4950000e+003, 1.9120000e+003,
#        8.5240000e+003, 2.0000000e+110, 5.0490000e+003, 8.8000000e+001,
#        5.2000000e+002, 3.4500000e+002, 7.3360000e+003, 1.0040000e+003,
#        3.6400000e+002, 9.8192000e+004, 1.6700000e+002, 2.4500000e+002,
#        2.0000000e+069, 3.8520000e+003, 7.0500000e+002, 1.0800000e+003,
#        5.1700000e+002, 2.3270000e+005, 4.4800000e+002, 7.0000000e+003,
#        4.8000000e+001, 7.2000000e+001, 3.7830000e+003, 7.3900000e+002,
#        2.6600000e+002, 9.0000000e+008, 1.1540000e+003, 2.9000000e+002,
#        2.8600000e+002, 4.0000000e+003, 3.7000000e+001, 9.0970000e+003,
#        4.6890000e+003, 4.1050000e+003, 4.1900000e+002, 3.9000000e+001,
#        3.5000000e+001, 9.1300000e+008, 3.4100000e+002, 8.4000000e+001,
#        2.2200000e+002, 9.0000000e+096, 4.4600000e+002, 4.5000000e+001,
#        2.2110000e+003, 1.0000000e+009, 2.6700000e+002, 5.0000000e+018,
#        3.8000000e+001, 2.0500000e+002, 8.8100000e+002, 9.1000000e+001,
#        4.0000000e+001, 2.4400000e+002, 3.3100000e+002, 7.5200000e+002,
#        6.9300000e+002, 7.3000000e+001, 8.4820000e+003, 9.7220000e+003,
#        2.7890000e+003, 6.8000000e+001, 6.6350000e+003, 9.2200000e+002,
#        8.4090000e+003, 5.8600000e+002, 1.7900000e+002, 6.0000000e+001,
#        1.4380000e+003, 2.4700000e+002, 5.5100000e+002, 7.9900000e+002,
#        1.7400000e+002, 1.1100000e+002, 1.2150000e+003, 1.6600000e+002,
#        1.3000000e+002, 8.6400000e+002, 2.0000000e+005, 4.2000000e+001,
#        4.1000000e+032, 8.0000000e+001, 4.6600000e+002, 2.7700000e+002,
#        8.7000000e+001, 1.7059000e+004, 4.0000000e+004, 8.0039200e+005,
#        8.5400000e+003, 7.9200000e+002, 9.3000000e+001, 9.1500000e+002,
#        6.3000000e+002, 3.8000000e+002, 7.7200000e+002, 2.5300000e+002,
#        4.3400000e+002, 4.6000000e+001, 4.1100000e+002, 8.4600000e+002,
#        5.3500000e+002, 4.9300000e+002, 7.1100000e+002, 2.3400000e+002,
#        9.7240000e+003, 7.6730000e+003, 8.8900000e+002, 7.0100000e+002,
#        9.6700000e+002, 1.0500000e+002, 4.0000000e+008, 7.0300000e+002,
#        1.4900000e+002, 8.0400000e+002, 2.0100000e+002,            inf,
#        6.0000000e+008, 7.1800000e+002, 8.1813700e+005, 9.0900000e+002,
#        2.0400000e+005, 2.9100000e+002, 3.0000000e+007, 8.7800000e+002,
#        1.0400000e+002, 9.5000000e+001, 8.0300000e+002, 2.3700000e+002,
#        1.8300000e+002, 7.1010000e+003, 4.3360000e+003, 8.4500000e+002,
#        2.0300000e+002, 7.9000000e+010, 2.7300000e+002, 8.8000000e+007,
#        4.0200000e+002, 6.0600000e+002, 6.2600000e+002, 8.7110000e+003,
#        6.1100000e+002, 1.8000000e+002, 6.4000000e+001, 7.7000000e+001,
#        5.7100000e+002, 2.0700000e+002, 7.9000000e+001, 7.5000000e+001,
#        4.3300000e+002, 6.1430000e+003, 6.9500000e+002, 8.6970000e+003,
#        4.1000000e+002, 2.7516000e+004, 1.0280000e+003, 5.4950000e+003,
#        5.2670000e+003, 1.0200000e+002, 5.8000000e+002, 8.4833100e+005,
#        5.4630000e+003, 2.8360000e+003, 2.8400000e+002, 4.1300000e+002,
#        4.0800000e+002, 4.6690000e+003, 7.2000000e+002, 5.1600000e+003,
#        2.0800000e+002, 5.6600000e+002, 7.5800000e+002, 2.1800000e+002,
#        2.7550000e+003, 5.0800000e+002, 4.3600000e+002, 5.5000000e+002,
#        3.9500000e+002, 1.4300000e+002, 3.5200000e+002, 2.2060000e+003,
#        2.4912000e+004, 9.3500000e+002, 7.4690000e+003, 8.2690000e+003,
#        8.1000000e+001, 6.0000000e+003, 2.6840000e+003, 9.1209500e+005,
#        8.0200000e+002, 9.7700000e+002, 6.3700000e+002, 8.1800000e+002,
#        3.0000000e+005, 7.4300000e+002, 2.3100000e+002, 2.2800000e+002,
#        2.4800000e+002, 4.0000000e+009, 9.7000000e+001, 6.9000000e+004,
#        9.0000000e+001, 5.0215000e+004, 6.4300000e+002, 8.2250000e+003,
#        3.2630000e+003, 5.1000000e+002, 7.4000000e+001, 1.2500000e+002,
#        7.5300000e+002, 2.8800000e+002, 7.9100000e+002, 8.6000000e+001,
#        2.4900000e+002, 9.3200000e+002, 5.7955000e+004, 8.4200000e+002,
#        4.6396000e+004, 9.8100000e+010, 2.1900000e+002, 1.5200000e+002,
#        5.1600000e+002, 6.9200000e+002, 5.9790000e+003, 8.9900000e+002,
#        6.4500000e+002, 2.7600000e+002, 1.0100000e+002, 3.5334000e+004,
#        9.0200000e+002, 5.0000000e+076, 7.4400000e+002, 2.1400000e+002,
#        4.4585999e+007, 5.9400000e+002, 4.4100000e+002, 6.7600000e+002,
#        4.2400000e+002, 1.4200000e+002, 2.6420000e+003, 1.5100000e+002,
#        7.5350000e+003, 2.2900000e+002, 8.9634000e+004, 2.1700000e+002,
#        4.4200000e+002, 1.8060000e+003, 1.1300000e+002, 2.9452000e+004,
#        7.1000000e+001, 8.9000000e+001, 2.3600000e+002, 8.6000000e+002,
#        3.3800000e+002, 5.8800000e+002, 2.7500000e+002, 8.8800000e+002,
#        3.5460000e+003, 7.3700000e+002, 5.3300000e+002, 9.3900000e+002,
#        8.5000000e+001, 1.0800000e+002, 4.8300000e+002, 2.4200000e+007,
#        6.0000000e+085, 2.3630000e+004, 1.8700000e+002, 3.6720000e+003,
#        6.4700000e+002, 1.0600000e+002, 4.2890000e+003, 6.4850000e+003,
#        6.0800000e+002, 3.2753500e+005, 3.5000000e+008, 5.9900000e+002,
#        9.2000000e+009, 7.0200000e+002, 7.7000000e+002, 2.7400000e+002,
#        6.3900000e+007, 3.7730000e+003, 2.5700000e+002, 6.8000000e+003,
#        9.2500000e+002, 2.8030000e+003, 7.0900000e+002, 7.8700000e+002,
#        9.8400000e+002, 1.9582000e+004, 2.0400000e+002, 9.0800000e+002,
#        3.9980000e+003, 6.0000000e+064, 2.2600000e+002, 5.0000000e+002,
#        4.4000000e+001, 5.8900000e+002, 9.9000000e+001, 3.3900000e+002,
#        7.2700000e+002, 7.9000000e+003, 2.2400000e+002, 8.3000000e+001,
#        1.1000000e+002, 3.2700000e+002, 3.7000000e+002, 6.3617800e+005,
#        4.9900000e+002, 5.6500000e+002, 2.4040000e+003, 9.4800000e+002,
#        4.2800000e+002, 7.3650500e+005, 1.5900000e+002, 7.5700000e+002,
#        3.6800000e+002, 8.2310000e+003, 8.4700000e+002, 3.5400000e+002,
#        5.8000000e+001, 1.3100000e+003, 6.6740000e+003, 9.1000000e+002,
#        4.5800000e+002, 3.1620000e+003, 5.0200000e+002, 9.5400000e+002,
#        5.4500000e+002, 9.5760000e+003, 4.2000000e+005, 6.1360000e+003,
#        5.3800000e+002, 8.8200000e+002, 8.1300000e+002, 1.0840000e+003,
#        3.8600000e+002, 9.3600000e+002, 3.0900000e+002, 5.4517900e+005,
#        7.4550000e+003, 2.8500000e+002, 1.9400000e+002, 5.0000000e+006,
#        3.3600000e+002, 5.0700000e+002, 1.9200000e+002, 1.9500000e+002,
#        6.9900000e+002, 5.6000000e+002, 6.7000000e+002, 9.6192000e+004,
#        6.7500000e+002, 3.5700000e+002, 7.8600000e+002, 7.0000000e+052,
#        2.3310000e+003, 1.1500000e+002, 7.7800000e+002, 8.9293000e+004,
#        1.7100000e+002, 7.0700000e+002, 3.7800000e+002, 1.0000000e+018,
#        4.4000000e+003, 1.9600000e+002, 5.5600000e+002, 9.0300000e+002,
#        9.8300000e+002, 9.5850000e+003, 3.1632000e+004, 8.0000000e+008,
#        3.9900000e+002, 6.7800000e+002, 5.2400000e+002, 3.2900000e+002,
#        8.3550000e+003, 8.2000000e+001, 2.6100000e+002, 8.9100000e+002,
#        9.9700000e+002, 3.8800000e+002, 9.6540000e+003, 3.0860000e+003,
#        4.1800000e+002, 8.1960000e+003, 2.4300000e+002, 9.8200000e+002,
#        4.7000000e+002, 7.1900000e+002, 1.0160000e+003, 3.3370000e+003,
#        2.2780000e+003, 4.4380000e+003, 8.2700000e+002, 5.7200000e+002,
#        7.0000000e+006, 2.4000000e+037, 6.1640000e+003, 4.2500000e+002,
#        7.6900000e+002, 8.7000000e+002, 9.0000000e+013, 2.1600000e+002,
#        9.0070000e+003, 9.5300000e+002, 6.1400000e+002, 9.9270000e+003,
#        4.5200000e+002, 7.2990000e+003, 3.1398300e+005, 1.0000000e+008,
#        1.7800000e+002, 6.3100000e+002, 4.2892000e+004, 9.6000000e+001,
#        6.0100000e+002, 6.0680000e+003, 5.6400000e+002, 8.8729000e+004,
#        7.6970000e+003, 8.4080000e+004, 1.1800000e+002, 3.4900000e+002,
#        3.3400000e+002, 4.4550700e+005, 1.5800000e+002, 7.1300000e+002,
#        6.2000000e+063, 8.8000000e+002, 1.3600000e+002, 2.7908000e+004,
#        9.7800000e+002, 3.6920000e+003, 8.3100000e+002, 2.0200000e+002,
#        6.8000000e+004, 5.6653000e+004, 4.6100000e+002, 8.7400000e+002,
#        5.7000000e+002, 4.7850000e+003, 2.5000000e+002, 2.9050000e+003,
#        7.2600000e+002, 1.7500000e+002, 6.9700000e+002, 5.9930000e+003,
#        4.5450000e+003, 9.0000000e+006, 1.7760000e+003, 7.4700000e+002,
#        8.7500000e+002, 7.6800000e+002, 4.0400000e+002, 7.9700000e+002,
#        7.7400000e+002, 4.3200000e+084, 5.7300000e+002, 1.8400000e+002,
#        8.0800000e+002, 1.5238000e+004, 5.5400000e+002, 9.0000000e+002,
#        1.2230000e+003, 9.5360000e+003, 1.4800000e+002, 1.4430000e+009,
#        4.0278000e+004, 1.6410000e+003, 1.6000000e+002, 2.7990000e+003,
#        3.0000000e+002, 2.2700000e+002, 6.6200000e+002, 7.6220000e+003,
#        5.9654000e+004, 9.7100000e+002, 5.2990000e+003, 9.2100000e+003,
#        7.3300000e+002, 5.2800000e+002, 9.8700000e+002, 7.4200000e+002,
#        2.1100000e+002, 5.1390000e+003, 9.1900000e+078, 1.8100000e+002,
#        5.7800000e+002, 2.5100000e+002, 1.8630000e+003, 6.0400000e+002,
#        6.7000000e+001, 4.1400000e+002, 8.7930000e+003, 2.7900000e+002,
#        4.7500000e+002, 1.2650000e+003, 9.8000000e+001, 9.2800000e+002,
#        9.5100000e+002, 1.3600000e+009, 6.5800000e+002, 3.0400000e+002,
#        9.7200000e+002, 4.8500000e+002, 7.0000000e+002, 6.1000000e+001,
#        9.7300000e+002, 1.2200000e+002, 2.0500000e+003, 5.0000000e+033,
#        9.1300000e+002, 5.0000000e+009, 8.3500000e+002, 1.7350000e+003,
#        9.4870000e+003, 7.9500000e+002, 3.0800000e+002, 7.3100000e+002,
#        1.3490000e+003, 9.7900000e+002, 8.4900000e+002, 7.5400000e+002,
#        2.0540000e+003, 7.5100000e+002, 1.1070000e+003, 7.4170000e+003,
#        7.6140000e+003, 1.9100000e+002, 5.3900000e+002, 8.7430000e+003,
#        2.7626000e+004, 1.2100000e+002, 6.4800000e+002, 7.7160000e+003,
#        5.3000000e+002, 6.9400000e+002, 9.0890000e+004, 5.3840000e+003,
#        8.4350000e+003, 4.8800000e+002, 3.7330000e+003, 2.4220000e+003,
#        1.8900000e+002, 5.2900000e+002, 7.6000000e+006, 7.0000000e+008,
#        7.8960000e+003, 1.2270000e+003, 9.0600000e+002, 3.7380000e+003,
#        4.4900000e+002, 7.9600000e+002, 4.4700000e+002, 8.0322000e+004,
#        5.7700000e+002, 9.6400000e+002, 6.1370000e+003, 2.6430000e+003,
#        8.0240000e+003, 7.6880000e+003, 6.9226000e+004, 3.2697000e+004,
#        5.4687000e+004, 4.4400000e+002, 5.8700000e+002, 7.0000000e+007])

# %% [markdown]
# ## Eliminazione dei valori negativi

# %%
tweets['retweet_count'] = tweets['retweet_count'].abs()
tweets['reply_count'] = tweets['reply_count'].abs()
tweets['favorite_count'] = tweets['favorite_count'].abs()
tweets['num_hashtags'] = tweets['num_hashtags'].abs()
tweets['num_mentions'] = tweets['num_mentions'].abs()
tweets['num_urls'] = tweets['num_urls'].abs()

# %% [markdown]
# ## Eliminazione dei valori inf

# %%
tweets.replace(math.inf, math.nan, inplace=True)
tweets.replace('inf', math.nan, inplace=True)

# %% [markdown]
# ## Manage duplicates:

# %% [markdown]
# ### Dropping duplicates:

# %%
tweets.drop_duplicates(inplace=True)

# %% [markdown]
# ### Find and replace duplicated 'id'

# %%
mask = tweets.duplicated('id', keep=False)
tweets.loc[mask, 'id'] = -1

# %% [markdown]
# ## Replacing NaN values:

# %% [markdown]
# ### Replace NaN values in 'id'

# %% [markdown]
# Replace nan values with a value (-1) that indicates that this information is missing

# %%
tweets.loc[tweets['id'].isna(), 'id'] = -1

# %% [markdown]
# ### Replacing NaN values in 'num_hashtags', 'num_urls' and 'num_mentions' by infer from the tweet's text

# %%
tweets['infer_hashtags'] = tweets.text.str.count('#')
tweets['infer_mentions'] = tweets.text.str.count('@')
tweets['infer_urls'] = tweets.text.str.count('http://')

tweets['num_hashtags'] = tweets['num_hashtags'].fillna(tweets['infer_hashtags'])
tweets['num_mentions'] = tweets['num_mentions'].fillna(tweets['infer_mentions'])
tweets['num_urls'] = tweets['num_urls'].fillna(tweets['infer_urls'])

tweets.drop(columns=['infer_hashtags', 'infer_mentions', 'infer_urls'], inplace=True)

# %% [markdown]
# ### Replacing NaN values with the median of the user

# %%
t = tweets
user_median = t.groupby('user_id', as_index=False).median()
user_median.rename(columns={
    'retweet_count' : 'retweet_median',
    'reply_count' : 'reply_median',
    'favorite_count' : 'favorite_median',
    'num_hashtags' : 'hashtags_median',
    'num_urls' : 'urls_median',
    'num_mentions' : 'mentions_median'
}, inplace=True)
user_median.drop(columns=['id'], inplace=True)
tweets = t.merge(user_median, on='user_id')

#sostituzione valori
tweets['retweet_count'] = tweets['retweet_count'].fillna(tweets['retweet_median'])
tweets['reply_count'] = tweets['reply_count'].fillna(tweets['reply_median'])
tweets['favorite_count'] = tweets['favorite_count'].fillna(tweets['favorite_median'])
tweets['num_hashtags'] = tweets['num_hashtags'].fillna(tweets['hashtags_median'])
tweets['num_mentions'] = tweets['num_mentions'].fillna(tweets['mentions_median'])
tweets['num_urls'] = tweets['num_urls'].fillna(tweets['urls_median'])

tweets.drop(columns=['retweet_median', 'reply_median', 'favorite_median', 'hashtags_median', 'mentions_median', 'urls_median'], \
            inplace=True)

# %% [markdown]
# ### Fill the remained NaN values with the median of the attribute

# %%
tweets['retweet_count'] = tweets['retweet_count'].fillna(tweets['retweet_count'].median())
tweets['reply_count'] = tweets['reply_count'].fillna(tweets['reply_count'].median())
tweets['favorite_count'] = tweets['favorite_count'].fillna(tweets['favorite_count'].median())
tweets['num_hashtags'] = tweets['num_hashtags'].fillna(tweets['num_hashtags'].median())
tweets['num_mentions'] = tweets['num_mentions'].fillna(tweets['num_mentions'].median())
tweets['num_urls'] = tweets['num_urls'].fillna(tweets['num_urls'].median())

# %% [markdown]
# ## Replacing invalid 'created_at' with symbolic date (01/01/2000)

# %%
tweets.loc[(tweets.created_at < datetime.strptime("2006-07-15 00:00:00", "%Y-%m-%d %H:%M:%S")) | \
    (tweets.created_at > datetime.now()),'created_at'] = datetime.strptime("2000-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")

# %%
backup = tweets

# %%
tweets = backup

# %% [markdown]
# ## Manage outliers

# %%
tweets.loc[tweets['retweet_count'] > tweets['retweet_count'].quantile(.95), 'retweet_count'] = tweets['retweet_count'].median()
tweets.loc[tweets['reply_count'] > tweets['reply_count'].quantile(.9999), 'reply_count'] = tweets['reply_count'].median()
tweets.loc[tweets['favorite_count'] > tweets['favorite_count'].quantile(.995), 'favorite_count'] = tweets['favorite_count'].median()
tweets.loc[tweets['num_hashtags'] > tweets['num_hashtags'].quantile(.999), 'num_hashtags'] = tweets['num_hashtags'].median()
tweets.loc[tweets['num_mentions'] > tweets['num_mentions'].quantile(.999), 'num_mentions'] = tweets['num_mentions'].median()
tweets.loc[tweets['num_urls'] > tweets['num_urls'].quantile(.9999), 'num_urls'] = tweets['num_urls'].median()

# %%
fig = plt.figure(figsize=(20, 23))
fig_dims = (3, 2)
fig.subplots_adjust(hspace=0.4, wspace=0.4)

######
plt.subplot2grid(fig_dims, (0,0))
tweets.boxplot(column=['favorite_count'])

######
plt.subplot2grid(fig_dims, (0,1))
tweets.boxplot(column=['retweet_count'])

######
plt.subplot2grid(fig_dims, (1,0))
tweets.boxplot(column=['reply_count'])

######
plt.subplot2grid(fig_dims, (1,1))
tweets.boxplot(column=['num_urls'])

######
plt.subplot2grid(fig_dims, (2,0))
tweets.boxplot(column=['num_hashtags'])

######
plt.subplot2grid(fig_dims, (2,1))
tweets.boxplot(column=['num_mentions'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Tweets indicators

# %% [markdown]
# ### Number of special character:

# %%
special = '[(|!£$%&/=?^@#§,.;:-_<>ç@)]' # Define special characters
tweets['special'] = tweets['text'].str.count(special) # Count them
tweets['special'] = tweets['special'].fillna(0)
tweets['special'] = tweets['special'].astype(int)

# %% [markdown]
# ### Text lenght:

# %%
tweets['text_lenght'] = tweets['text'].str.len()
tweets['text_lenght'] = tweets['text_lenght'].fillna(0)
tweets['text_lenght'] = tweets['text_lenght'].astype(int)

# %%
tweets['reply_count'].describe()
# Out:
# count    1.127870e+07
# mean     2.889384e-03
# std      1.395678e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.400000e+01
# Name: reply_count, dtype: float64

# %% [markdown]
# ## Write a new file '.csv' with all the modify done

# %%
tweets.to_csv('../new_tweets.csv')

# %% [markdown]
# # User data Preparation

# %% [markdown]
# This part use the previous modify done to the tweets dataframe.

# %%
users = pd.read_csv('../users.csv')
#tweets = pd.read_csv('new_tweets.csv', lineterminator='\n', index_col=0)

# %%
users.info()
users.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11508 entries, 0 to 11507
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11508 non-null  int64
#  1   name            11507 non-null  object
#  2   lang            11508 non-null  object
#  3   bot             11508 non-null  int64
#  4   created_at      11508 non-null  object
#  5   statuses_count  11109 non-null  float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 539.6+ KB
# id                  int64
# name               object
# lang               object
# bot                 int64
# created_at         object
# statuses_count    float64
# dtype: object

# %% [markdown]
# ## Column type conversion

# %%
users['id'] = pd.to_numeric(users['id'], errors='coerce')
users['statuses_count'] = pd.to_numeric(users['statuses_count'], errors='coerce')
users['created_at'] = pd.to_datetime(users['created_at'], errors='coerce')

# %% [markdown]
# ## Elimination of negative values

# %%
users['statuses_count'] = users['statuses_count'].abs()

# %% [markdown]
# ## Lang Correction

# %%
users['lang'] = users['lang'].str.lower()
users.rename(columns={
    'id' : 'user_id',
    'created_at' : 'subscribing_date'
}, inplace=True)
nal = users[(users['lang'] == 'select language...') | (users['lang'] == 'xx-lc')]

text_nal = tweets.merge(nal, on='user_id')
text_nal
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1204: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#                 id       user_id  retweet_count  reply_count  favorite_count  \
# 0     4.912745e+17  2.955215e+07            0.0          0.0             0.0
# 1     4.886930e+17  2.955215e+07            0.0          0.0             0.0
# 2     4.854109e+17  2.955215e+07            0.0          0.0             0.0
# 3     1.683542e+15  2.955215e+07            0.0          0.0             0.0
# 4     7.055459e+09  2.955215e+07            0.0          0.0             0.0
# ...            ...           ...            ...          ...             ...
# 2191  5.910286e+17  2.956614e+09           61.0          0.0             0.0
# 2192  4.789901e+10  2.956614e+09            3.0          0.0             0.0
# 2193  5.939970e+17  2.956614e+09            0.0          0.0             0.0
# 2194  7.268000e+16  2.956614e+09            3.0          0.0             1.0
# 2195  6.322436e+09  2.956614e+09            3.0          0.0             0.0
#
#       num_hashtags  num_urls  num_mentions          created_at  \
# 0              0.0       0.0           0.0 2019-07-23 17:32:30
# 1              0.0       0.0           0.0 2019-07-16 14:34:25
# 2              0.0       0.0           0.0 2019-07-07 13:12:33
# 3              0.0       0.0           0.0 2019-07-16 20:58:50
# 4              0.0       0.0           0.0 2020-02-27 20:17:18
# ...            ...       ...           ...                 ...
# 2191           0.0       1.0           1.0 2020-04-23 23:59:43
# 2192           2.0       0.0           2.0 2020-03-19 10:54:49
# 2193           0.0       1.0           0.0 2020-05-02 04:35:05
# 2194           0.0       0.0           3.0 2020-05-01 19:38:48
# 2195           3.0       0.0           1.0 2020-04-13 20:18:05
#
#                                                    text  special  text_lenght  \
# 0     Spent the majority of my day drawing around, c...       10          111
# 1       We all love dem cuddles. http://t.co/fPrcnUfacS       10           47
# 2                  Dog sitting until 8 tonight. Again..        5           36
# 3                                                   NaN        0            0
# 4               The chocolate is soooooooooooo amazing.        2           39
# ...                                                 ...      ...          ...
# 2191  RT @LivvyAllison: If you are reading the front...       20          120
# 2192  RT @sophieraworth: Last night over Sweden... R...       30          137
# 2193  I think even super heroes should rest at weeke...       12           75
# 2194      @annabf @CampbellLiveNZ @UniteUnion well done        9           45
# 2195  RT @EverydaySexism: Waiting for #HillarysBigAn...       27          140
#
#               name                lang  bot    subscribing_date  \
# 0           Chloe                xx-lc    0 2014-04-09 21:36:02
# 1           Chloe                xx-lc    0 2014-04-09 21:36:02
# 2           Chloe                xx-lc    0 2014-04-09 21:36:02
# 3           Chloe                xx-lc    0 2014-04-09 21:36:02
# 4           Chloe                xx-lc    0 2014-04-09 21:36:02
# ...            ...                 ...  ...                 ...
# 2191  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2192  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2193  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2194  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2195  Leanne Arker  select language...    0 2020-01-05 00:09:59
#
#       statuses_count
# 0            15398.0
# 1            15398.0
# 2            15398.0
# 3            15398.0
# 4            15398.0
# ...              ...
# 2191            57.0
# 2192            57.0
# 2193            57.0
# 2194            57.0
# 2195            57.0
#
# [2196 rows x 17 columns]

# %%
text_nal[text_nal['name'] == 'Leanne Arker'].head(3)
# Out:
#                 id       user_id  retweet_count  reply_count  favorite_count  \
# 2130  5.866970e+17  2.956614e+09            0.0          0.0             0.0
# 2131  5.601363e+17  2.956614e+09            0.0          0.0             0.0
# 2132  5.751565e+17  2.956614e+09            0.0          0.0             0.0
#
#       num_hashtags  num_urls  num_mentions          created_at  \
# 2130           0.0       0.0           1.0 2020-04-12 01:07:12
# 2131           0.0       0.0           2.0 2020-01-29 18:04:45
# 2132           0.0       0.0           1.0 2020-03-11 04:49:27
#
#                                                    text  special  text_lenght  \
# 2130  @bernardchickey I've heard of something called...        7          137
# 2131  RT @stephenfry: If physical diseases were trea...       16          110
# 2132  @Hilary_Barry Gives new meaning to the term sl...        5           62
#
#               name                lang  bot    subscribing_date  \
# 2130  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2131  Leanne Arker  select language...    0 2020-01-05 00:09:59
# 2132  Leanne Arker  select language...    0 2020-01-05 00:09:59
#
#       statuses_count
# 2130            57.0
# 2131            57.0
# 2132            57.0

# %% [markdown]
# ##### Users without a language are en

# %%
users['lang'].replace('select language...', 'en', inplace=True)
users['lang'].replace('xx-lc', 'en', inplace=True)

# %% [markdown]
# ## Calculate for each user how many tweets we have in tweets.csv

# %%
users = users.merge(tweets[['user_id', 'id']].groupby('user_id', as_index=False).count(), on='user_id')
users = users.rename(columns={'id' : 'count'})
users.head(3)
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       user_id              name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986   Lamonica Raborn   en    1 2019-02-22 18:00:42            76.0
# 1  2358850842     Lourie Botton   en    0 2019-02-26 03:02:32            54.0
# 2   137959629  Dadan Syarifudin   en    1 2015-04-30 07:09:56             3.0
#
#    count
# 0    132
# 1    122
# 2      4

# %%
users.loc[users['statuses_count'] < users['count'], 'statuses_count'] = users['count']

# %% [markdown]
# ## Summing parameters in users (likes received, retweet and reply received)

# %%
new_tweets = tweets.filter(['user_id', 'retweet_count', 'reply_count', 'favorite_count', 'num_hashtags', 'num_urls', 'num_mentions'], axis=1)
new_users = users.merge(new_tweets.groupby('user_id').sum(), on='user_id')
new_users = new_users.rename(columns={
    'retweet_count' : 'retweet_received',
    'reply_count' : 'reply_received',
    'favorite_count' : 'favorite_received',
    'num_hashtags' : 'hashtag_used',
    'num_urls' : 'urls_used',
    'num_mentions' : 'mentions_used'}, 
    errors='raise'
)
new_users.head()
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       user_id              name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986   Lamonica Raborn   en    1 2019-02-22 18:00:42           132.0
# 1  2358850842     Lourie Botton   en    0 2019-02-26 03:02:32           122.0
# 2   137959629  Dadan Syarifudin   en    1 2015-04-30 07:09:56             4.0
# 3   466124818    Carletto Focia   it    1 2017-01-18 02:49:18          1439.0
# 4  2571493866         MBK Ebook   en    0 2019-06-18 19:30:21          7085.0
#
#    count  retweet_received  reply_received  favorite_received  hashtag_used  \
# 0    132               5.0             0.0                5.0          13.0
# 1    122               3.0             0.0                6.0           4.0
# 2      4               0.0             0.0                0.0           0.0
# 3   1439            1190.0             0.0              259.0         107.0
# 4   3656              62.0             0.0              226.0         479.0
#
#    urls_used  mentions_used
# 0        0.0           37.0
# 1        0.0           41.0
# 2        0.0            0.0
# 3       36.0            9.0
# 4        3.0         1936.0

# %%
new_users[\
    (new_users['retweet_received'].isna() == True) |\
    (new_users['reply_received'].isna() == True) |\
    (new_users['favorite_received'].isna() == True) |\
    (new_users['hashtag_used'].isna() == True) |\
    (new_users['urls_used'].isna() == True) |\
    (new_users['mentions_used'].isna() == True)
        ].head()
# Out:
# Empty DataFrame
# Columns: [user_id, name, lang, bot, subscribing_date, statuses_count, count, retweet_received, reply_received, favorite_received, hashtag_used, urls_used, mentions_used]
# Index: []

# %%
new_users['reply_received'] = new_users['reply_received'].fillna(new_users['reply_received'].median())
new_users['retweet_received'] = new_users['retweet_received'].fillna(new_users['retweet_received'].median())
new_users['statuses_count'] = new_users['statuses_count'].fillna(new_users['statuses_count'].median())

# %%
new_users['reply_received'] = new_users['reply_received'].astype(int)
new_users['retweet_received'] = new_users['retweet_received'].astype(int)
new_users['favorite_received'] = new_users['favorite_received'].astype(int)
new_users['hashtag_used'] = new_users['hashtag_used'].astype(int)
new_users['urls_used'] = new_users['urls_used'].astype(int)
new_users['mentions_used'] = new_users['mentions_used'].astype(int)
new_users['statuses_count'] = new_users['statuses_count'].astype(int)

# %% [markdown]
# ## Ratio

# %%
new_users['favorite_avg'] = round(new_users['favorite_received'] / new_users['count'], 2)
new_users.head(3)
# Out:
#       user_id              name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986   Lamonica Raborn   en    1 2019-02-22 18:00:42             132
# 1  2358850842     Lourie Botton   en    0 2019-02-26 03:02:32             122
# 2   137959629  Dadan Syarifudin   en    1 2015-04-30 07:09:56               4
#
#    count  retweet_received  reply_received  favorite_received  hashtag_used  \
# 0    132                 5               0                  5            13
# 1    122                 3               0                  6             4
# 2      4                 0               0                  0             0
#
#    urls_used  mentions_used  favorite_avg
# 0          0             37          0.04
# 1          0             41          0.05
# 2          0              0          0.00

# %%
new_users['retweet_avg'] = round(new_users['retweet_received'] / new_users['count'], 2)
new_users['reply_avg'] = round(new_users['reply_received'] / new_users['count'], 2)
new_users['urls_avg'] = round(new_users['urls_used'] / new_users['count'], 2)
new_users['mentions_avg'] = round(new_users['mentions_used'] / new_users['count'], 2)
new_users['hashtags_avg'] = round(new_users['hashtag_used'] / new_users['count'], 2)

# %% [markdown]
# ## Avg text lenght per user

# %%
mean_tweets = tweets[['user_id', 'text_lenght']].groupby('user_id', as_index=False).mean()

# %%
mean_tweets['user_id'] = mean_tweets['user_id'].astype(int)
mean_tweets['text_lenght'] = round(mean_tweets['text_lenght'])
mean_tweets['text_lenght'] = mean_tweets['text_lenght'].astype(int)
mean_tweets = mean_tweets.rename(columns={'text_lenght':'avg_lenght'})

# %%
new_users = new_users.merge(mean_tweets, on='user_id')
new_users.head(2)
# Out:
#       user_id             name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986  Lamonica Raborn   en    1 2019-02-22 18:00:42             132
# 1  2358850842    Lourie Botton   en    0 2019-02-26 03:02:32             122
#
#    count  retweet_received  reply_received  favorite_received  hashtag_used  \
# 0    132                 5               0                  5            13
# 1    122                 3               0                  6             4
#
#    urls_used  mentions_used  favorite_avg  retweet_avg  reply_avg  urls_avg  \
# 0          0             37          0.04         0.04        0.0       0.0
# 1          0             41          0.05         0.02        0.0       0.0
#
#    mentions_avg  hashtags_avg  avg_lenght
# 0          0.28          0.10          62
# 1          0.34          0.03          69

# %%
date_tweets = tweets
date_tweets['year'] = date_tweets['created_at'].dt.year
date_tweets['month'] = date_tweets['created_at'].dt.month
date_tweets['day'] = date_tweets['created_at'].dt.day
date_tweets['hour'] = date_tweets['created_at'].dt.hour

# %%
date_years = date_tweets.groupby(by=['user_id', 'year', 'month']).count()

# %%
date_years['count'] = date_years['id']
date_years = date_years[['count']]
date_years.head(5)
# Out:
#                     count
# user_id year month
# 0.0     2019 3          1
#              9          1
#              10         1
#         2020 2          1
#              3          3

# %%
minimum = date_years.reset_index().groupby('user_id').min()
maximum = date_years.reset_index().groupby('user_id').max()
minimum = minimum[['year', 'month']].rename(columns={'year' : 'year_min', 'month' : 'month_min'})
maximum = maximum[['year', 'month']].rename(columns={'year' : 'year_max', 'month' : 'month_max'})

activity_period = minimum.merge(maximum, on='user_id')
activity_period['activity_period'] = (activity_period['year_max'] - activity_period['year_min'])*12 + activity_period['month_max'] - activity_period['month_min']
activity_period = activity_period.drop(columns=['year_min', 'year_max', 'month_min', 'month_max'])

# %%
txm = date_years.groupby('user_id').mean()
txm = txm.reset_index()
txm = txm.rename(columns={'count' : 'tweets_per_year'})
new_users = new_users.merge(txm, on='user_id')
new_users.head()
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       user_id              name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986   Lamonica Raborn   en    1 2019-02-22 18:00:42             132
# 1  2358850842     Lourie Botton   en    0 2019-02-26 03:02:32             122
# 2   137959629  Dadan Syarifudin   en    1 2015-04-30 07:09:56               4
# 3   466124818    Carletto Focia   it    1 2017-01-18 02:49:18            1439
# 4  2571493866         MBK Ebook   en    0 2019-06-18 19:30:21            7085
#
#    count  retweet_received  reply_received  favorite_received  ...  urls_used  \
# 0    132                 5               0                  5  ...          0
# 1    122                 3               0                  6  ...          0
# 2      4                 0               0                  0  ...          0
# 3   1439              1190               0                259  ...         36
# 4   3656                62               0                226  ...          3
#
#    mentions_used  favorite_avg  retweet_avg  reply_avg  urls_avg  \
# 0             37          0.04         0.04        0.0      0.00
# 1             41          0.05         0.02        0.0      0.00
# 2              0          0.00         0.00        0.0      0.00
# 3              9          0.18         0.83        0.0      0.03
# 4           1936          0.06         0.02        0.0      0.00
#
#    mentions_avg  hashtags_avg  avg_lenght  tweets_per_year
# 0          0.28          0.10          62        22.000000
# 1          0.34          0.03          69        20.333333
# 2          0.00          0.00          19         4.000000
# 3          0.01          0.07          87       179.875000
# 4          0.53          0.13          72       731.200000
#
# [5 rows x 21 columns]

# %%
activity_period = activity_period.reset_index()
new_users = new_users.merge(activity_period, on='user_id')
new_users.head()
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#       user_id              name lang  bot    subscribing_date  statuses_count  \
# 0  2353593986   Lamonica Raborn   en    1 2019-02-22 18:00:42             132
# 1  2358850842     Lourie Botton   en    0 2019-02-26 03:02:32             122
# 2   137959629  Dadan Syarifudin   en    1 2015-04-30 07:09:56               4
# 3   466124818    Carletto Focia   it    1 2017-01-18 02:49:18            1439
# 4  2571493866         MBK Ebook   en    0 2019-06-18 19:30:21            7085
#
#    count  retweet_received  reply_received  favorite_received  ...  \
# 0    132                 5               0                  5  ...
# 1    122                 3               0                  6  ...
# 2      4                 0               0                  0  ...
# 3   1439              1190               0                259  ...
# 4   3656                62               0                226  ...
#
#    mentions_used  favorite_avg  retweet_avg  reply_avg  urls_avg  \
# 0             37          0.04         0.04        0.0      0.00
# 1             41          0.05         0.02        0.0      0.00
# 2              0          0.00         0.00        0.0      0.00
# 3              9          0.18         0.83        0.0      0.03
# 4           1936          0.06         0.02        0.0      0.00
#
#    mentions_avg  hashtags_avg  avg_lenght  tweets_per_year  activity_period
# 0          0.28          0.10          62        22.000000                5
# 1          0.34          0.03          69        20.333333                5
# 2          0.00          0.00          19         4.000000                0
# 3          0.01          0.07          87       179.875000               30
# 4          0.53          0.13          72       731.200000                4
#
# [5 rows x 22 columns]

# %%
g_sum = new_users['bot'].sum()
values = new_users['bot']/g_sum
new_users['Bot_Entropy'] = -(values*np.log(values))
users['Bot_Entropy'] = new_users['Bot_Entropy'].fillna(0)
users['Bot_Entropy'].sum()
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 8.718663567048953

# %%
#new_users.head(50)

#df1 = users.groupby('id',as_index=False,sort=False)['Count_Entropy'].sum()

# %%
new_users['sub_year'] = new_users['subscribing_date'].dt.year
new_users['sub_month'] = new_users['subscribing_date'].dt.month
new_users['sub_day'] = new_users['subscribing_date'].dt.day

# %%
max = tweets.groupby('user_id').max()
max = max[['retweet_count', 'reply_count', 'favorite_count']]
max = max.rename(columns={
    'retweet_count' : 'retweet_max',
    'reply_count' : 'reply_max',
    'favorite_count' : 'favorite_max'
})
# Out:
# /var/folders/h4/5wp1mt_n1k72n6zcf7wxd6bc0000gn/T/ipykernel_36212/2830521494.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   max = tweets.groupby('user_id').max()

# %%
max = max.reset_index()
new_users = new_users.merge(max, on='user_id')
new_users
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
#           user_id                name lang  bot    subscribing_date  \
# 0      2353593986     Lamonica Raborn   en    1 2019-02-22 18:00:42
# 1      2358850842       Lourie Botton   en    0 2019-02-26 03:02:32
# 2       137959629    Dadan Syarifudin   en    1 2015-04-30 07:09:56
# 3       466124818      Carletto Focia   it    1 2017-01-18 02:49:18
# 4      2571493866           MBK Ebook   en    0 2019-06-18 19:30:21
# ...           ...                 ...  ...  ...                 ...
# 11503  2911861962  Madrid Lae Maika .   en    0 2019-11-29 13:16:02
# 11504  1378532629           Clau Sato   en    0 2018-04-27 03:01:58
# 11505   126984069  ALMA LETICIA NUÑO    es    0 2015-03-29 17:01:24
# 11506  2383025796     Minnie Guadagno   en    1 2019-03-13 02:44:13
# 11507   933183398           Corvanna    en    0 2017-11-09 23:24:16
#
#        statuses_count  count  retweet_received  reply_received  \
# 0                 132    132                 5               0
# 1                 122    122                 3               0
# 2                   4      4                 0               0
# 3                1439   1439              1190               0
# 4                7085   3656                62               0
# ...               ...    ...               ...             ...
# 11503            1126   1120             19585               0
# 11504            3024   2088              7391               0
# 11505               7      7                 0               0
# 11506             105    105                 7               0
# 11507            5279   3694             51901               0
#
#        favorite_received  ...  avg_lenght  tweets_per_year  activity_period  \
# 0                      5  ...          62        22.000000                5
# 1                      6  ...          69        20.333333                5
# 2                      0  ...          19         4.000000                0
# 3                    259  ...          87       179.875000               30
# 4                    226  ...          72       731.200000                4
# ...                  ...  ...         ...              ...              ...
# 11503                 66  ...          52       224.000000                4
# 11504                449  ...          60       130.500000               31
# 11505                  0  ...          72         1.750000               31
# 11506                  9  ...          63        21.000000                4
# 11507                478  ...          52       923.500000                3
#
#        Bot_Entropy  sub_year  sub_month  sub_day  retweet_max  reply_max  \
# 0         0.001426      2019          2       22          1.0        0.0
# 1              NaN      2019          2       26          1.0        0.0
# 2         0.001426      2015          4       30          0.0        0.0
# 3         0.001426      2017          1       18        364.0        0.0
# 4              NaN      2019          6       18          3.0        0.0
# ...            ...       ...        ...      ...          ...        ...
# 11503          NaN      2019         11       29        391.0        0.0
# 11504          NaN      2018          4       27        395.0        0.0
# 11505          NaN      2015          3       29          0.0        0.0
# 11506     0.001426      2019          3       13          2.0        0.0
# 11507          NaN      2017         11        9        391.0        0.0
#
#        favorite_max
# 0               1.0
# 1               1.0
# 2               0.0
# 3              11.0
# 4               2.0
# ...             ...
# 11503           3.0
# 11504           4.0
# 11505           0.0
# 11506           1.0
# 11507           4.0
#
# [11508 rows x 29 columns]

# %%
new_users = new_users.drop(columns=['subscribing_date'])

# %%
#counting how much tweets have at least 1 retweet or favorite or reply
interaction_tweet = tweets[(tweets['favorite_count'] > 0) | (tweets['retweet_count'] > 0) | (tweets['reply_count'] > 0)]\
                          .groupby('user_id')['retweet_count'].count()
interaction_tweet = interaction_tweet.reset_index()
interaction_tweet = interaction_tweet.rename(columns={'retweet_count' : 'interaction_count'})
new_users = new_users.merge(interaction_tweet, on='user_id')
# Out:
# /Users/Koto/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(

# %%
users = new_users

# %% [markdown]
# ## Write new file csv

# %%
users.to_csv('../new_users.csv')
